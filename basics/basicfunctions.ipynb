# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/sajlabs/bitcoin.csv')

# %%
df
# Out:
#             Date         Close          High           Low          Open  \
# 0     2014-09-17    457.334015    468.174011    452.421997    465.864014
# 1     2014-09-18    424.440002    456.859985    413.104004    456.859985
# 2     2014-09-19    394.795990    427.834991    384.532013    424.102997
# 3     2014-09-20    408.903992    423.295990    389.882996    394.673004
# 4     2014-09-21    398.821014    412.425995    393.181000    408.084991
# ...          ...           ...           ...           ...           ...
# 4129  2026-01-06  93729.031250  94395.296875  91286.546875  93876.945312
# 4130  2026-01-07  91308.054688  93738.789062  90601.804688  93727.468750
# 4131  2026-01-08  91027.125000  91485.851562  89233.875000  91309.640625
# 4132  2026-01-09  90513.101562  91910.671875  89625.382812  91026.273438
# 4133  2026-01-10  90386.648438  90713.031250  90283.398438  90510.101562
#
#            Volume
# 0        21056800
# 1        34483200
# 2        37919700
# ...

# %%
print(df.head())
# Out:
#          Date       Close        High         Low        Open    Volume
# 0  2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 1  2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2  2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 3  2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 4  2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100

# %%
print(df.shape)
# Out:
# (4134, 6)

# %%
print(df.columns)
# Out:
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str')

# %%
print(df.dtypes)
# Out:
# Date          str
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# dtype: object

# %%
volume_df = df['Volume']

# %%
volume_df
# Out:
# 0          21056800
# 1          34483200
# 2          37919700
# 3          36863600
# 4          26580100
#            ...
# 4129    52430605257
# 4130    43461295053
# 4131    42386697030
# 4132    38305906684
# 4133    12385895282
# Name: Volume, Length: 4134, dtype: int64

# %%
print(volume_df.head())
# Out:
# 0    21056800
# 1    34483200
# 2    37919700
# 3    36863600
# 4    26580100
# Name: Volume, dtype: int64

# %%
print(volume_df)
# Out:
# 0          21056800
# 1          34483200
# 2          37919700
# 3          36863600
# 4          26580100
#            ...
# 4129    52430605257
# 4130    43461295053
# 4131    42386697030
# 4132    38305906684
# 4133    12385895282
# Name: Volume, Length: 4134, dtype: int64

# %%
print(df.loc[4131])
# Out:
# Date        2026-01-08
# Close        91027.125
# High      91485.851562
# Low          89233.875
# Open      91309.640625
# Volume     42386697030
# Name: 4131, dtype: object

# %%
df
# Out:
#             Date         Close          High           Low          Open  \
# 0     2014-09-17    457.334015    468.174011    452.421997    465.864014
# 1     2014-09-18    424.440002    456.859985    413.104004    456.859985
# 2     2014-09-19    394.795990    427.834991    384.532013    424.102997
# 3     2014-09-20    408.903992    423.295990    389.882996    394.673004
# 4     2014-09-21    398.821014    412.425995    393.181000    408.084991
# ...          ...           ...           ...           ...           ...
# 4129  2026-01-06  93729.031250  94395.296875  91286.546875  93876.945312
# 4130  2026-01-07  91308.054688  93738.789062  90601.804688  93727.468750
# 4131  2026-01-08  91027.125000  91485.851562  89233.875000  91309.640625
# 4132  2026-01-09  90513.101562  91910.671875  89625.382812  91026.273438
# 4133  2026-01-10  90386.648438  90713.031250  90283.398438  90510.101562
#
#            Volume
# 0        21056800
# 1        34483200
# 2        37919700
# ...

# %%
print(df)
# Out:
#             Date         Close          High           Low          Open  \
# 0     2014-09-17    457.334015    468.174011    452.421997    465.864014
# 1     2014-09-18    424.440002    456.859985    413.104004    456.859985
# 2     2014-09-19    394.795990    427.834991    384.532013    424.102997
# 3     2014-09-20    408.903992    423.295990    389.882996    394.673004
# 4     2014-09-21    398.821014    412.425995    393.181000    408.084991
# ...          ...           ...           ...           ...           ...
# 4129  2026-01-06  93729.031250  94395.296875  91286.546875  93876.945312
# 4130  2026-01-07  91308.054688  93738.789062  90601.804688  93727.468750
# 4131  2026-01-08  91027.125000  91485.851562  89233.875000  91309.640625
# 4132  2026-01-09  90513.101562  91910.671875  89625.382812  91026.273438
# 4133  2026-01-10  90386.648438  90713.031250  90283.398438  90510.101562
#
#            Volume
# 0        21056800
# 1        34483200
# 2        37919700
# ...

# %%
print(df.iloc[99])
# Out:
# Date      2014-12-25
# Close     319.007996
# High      322.670013
# Low       316.958008
# Open      322.286011
# Volume       9883640
# Name: 99, dtype: object

# %%
print(df.iloc[-1])
# Out:
# Date        2026-01-10
# Close     90386.648438
# High       90713.03125
# Low       90283.398438
# Open      90510.101562
# Volume     12385895282
# Name: 4133, dtype: object

# %%
print(df.tail(n=1))
# Out:
#             Date         Close         High           Low          Open  \
# 4133  2026-01-10  90386.648438  90713.03125  90283.398438  90510.101562
#
#            Volume
# 4133  12385895282

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4134 non-null   str
#  1   Close   4134 non-null   float64
#  2   High    4134 non-null   float64
#  3   Low     4134 non-null   float64
#  4   Open    4134 non-null   float64
#  5   Volume  4134 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 193.9 KB

# %%
subset = df[['Date', 'Volume']]

# %%
subset.head()
# Out:
#          Date    Volume
# 0  2014-09-17  21056800
# 1  2014-09-18  34483200
# 2  2014-09-19  37919700
# 3  2014-09-20  36863600
# 4  2014-09-21  26580100

# %%
subset.tail()
# Out:
#             Date       Volume
# 4129  2026-01-06  52430605257
# 4130  2026-01-07  43461295053
# 4131  2026-01-08  42386697030
# 4132  2026-01-09  38305906684
# 4133  2026-01-10  12385895282

# %%
print(df.loc[0])
# Out:
# Date      2014-09-17
# Close     457.334015
# High      468.174011
# Low       452.421997
# Open      465.864014
# Volume      21056800
# Name: 0, dtype: object

# %%
print(df.loc[99])
# Out:
# Date      2014-12-25
# Close     319.007996
# High      322.670013
# Low       316.958008
# Open      322.286011
# Volume       9883640
# Name: 99, dtype: object

# %%
print(df.tail(n=1))
# Out:
#             Date         Close         High           Low          Open  \
# 4133  2026-01-10  90386.648438  90713.03125  90283.398438  90510.101562
#
#            Volume
# 4133  12385895282

# %%
print(df.loc[[0,99,999]])
# Out:
#            Date        Close         High          Low         Open  \
# 0    2014-09-17   457.334015   468.174011   452.421997   465.864014
# 99   2014-12-25   319.007996   322.670013   316.958008   322.286011
# 999  2017-06-12  2659.629883  2997.260010  2518.560059  2953.219971
#
#          Volume
# 0      21056800
# 99      9883640
# 999  2569530112

# %%
print(df.iloc[1])
# Out:
# Date      2014-09-18
# Close     424.440002
# High      456.859985
# Low       413.104004
# Open      456.859985
# Volume      34483200
# Name: 1, dtype: object

# %%
print(df.iloc[-1])
# Out:
# Date        2026-01-10
# Close     90386.648438
# High       90713.03125
# Low       90283.398438
# Open      90510.101562
# Volume     12385895282
# Name: 4133, dtype: object

# %%
subset = df.loc[:,['High', 'Low']]

# %%
subset
# Out:
#               High           Low
# 0       468.174011    452.421997
# 1       456.859985    413.104004
# 2       427.834991    384.532013
# 3       423.295990    389.882996
# 4       412.425995    393.181000
# ...            ...           ...
# 4129  94395.296875  91286.546875
# 4130  93738.789062  90601.804688
# 4131  91485.851562  89233.875000
# 4132  91910.671875  89625.382812
# 4133  90713.031250  90283.398438
#
# [4134 rows x 2 columns]

# %%
subset = df.iloc[:,[2, 4, -1]]

# %%
subset
# Out:
#               High          Open       Volume
# 0       468.174011    465.864014     21056800
# 1       456.859985    456.859985     34483200
# 2       427.834991    424.102997     37919700
# 3       423.295990    394.673004     36863600
# 4       412.425995    408.084991     26580100
# ...            ...           ...          ...
# 4129  94395.296875  93876.945312  52430605257
# 4130  93738.789062  93727.468750  43461295053
# 4131  91485.851562  91309.640625  42386697030
# 4132  91910.671875  91026.273438  38305906684
# 4133  90713.031250  90510.101562  12385895282
#
# [4134 rows x 3 columns]

# %%
subset.plot()
# Out:
# <Axes: >

# %%
global_volume=df.groupby('Date')['Volume'].mean()

# %%
global_volume
# Out:
# Date
# 2014-09-17    2.105680e+07
# 2014-09-18    3.448320e+07
# 2014-09-19    3.791970e+07
# 2014-09-20    3.686360e+07
# 2014-09-21    2.658010e+07
#                   ...
# 2026-01-06    5.243061e+10
# 2026-01-07    4.346130e+10
# 2026-01-08    4.238670e+10
# 2026-01-09    3.830591e+10
# 2026-01-10    1.238590e+10
# Name: Volume, Length: 4134, dtype: float64

# %%
sns.pairplot(df)
